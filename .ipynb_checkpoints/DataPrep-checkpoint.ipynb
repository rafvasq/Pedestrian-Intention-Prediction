# %%
import pickle
import pandas as pd

dataPath = '../../PedestrianData/CleanData'

pd.__version__
# Out:
# ../../PedestrianData/CleanData
# '0.24.2'

# %% [markdown]
# #### Loading the data from pickle:

# %%
data = pd.read_pickle('./ALLDATA.pkl')
data.head()
# Out:
#                                        File Scenario Wait Time (s) PET (s)  \
# 0   Jonathan Yao/2--2018-08-7--11-40-27.txt        2        43.032       0
# 1  Jonathan Yao/14--2018-08-7--11-38-35.txt       14       9.42172    1000
# 2  Jonathan Yao/19--2018-08-7--11-39-16.txt       19       35.2602       0
# 3   Jonathan Yao/3--2018-08-7--11-32-11.txt        3       17.4219       0
# 4  Jonathan Yao/48--2018-08-7--11-34-41.txt       48       27.3343    1000
#
#   Distace to Collision Point Card ID Speed Limit Lane Width Minimum Gap  \
# 0                       1000       2          30          3         1.5
# 1                       1000      14          40        2.5           2
# 2                       1000      19          30          3         1.5
# 3                       1000       3          30          3           1
# 4                       1000      48          30       2.75           1
#
#   Mean Arrival Rate  ... Vrexp_Yes Heart_Currently Heart_Over the years  \
# ...

# %% [markdown]
# #### Removing folder names from file values:

# %%
for i in range(len(data)):
    data['File'].values[i] = data['File'].values[i].split('/')[1]
    
data['File'].head()
# Out:
# 0     2--2018-08-7--11-40-27.txt
# 1    14--2018-08-7--11-38-35.txt
# 2    19--2018-08-7--11-39-16.txt
# 3     3--2018-08-7--11-32-11.txt
# 4    48--2018-08-7--11-34-41.txt
# Name: File, dtype: object
